# %% [markdown]
# # Plate solving fits file

# %% [markdown]
# ## import modules
#
# 우선 필요한 모듈을 import합니다.

# %%
from pathlib import Path
from astropy.io import fits

import ysfitsutilpy as yfu

import _astro_utilities
import _Python_utilities

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 환경 설정

# %%
#%%
verbose = True
tryagain = False
trynightsky = True
#######################################################
BASEDIR = Path("/mnt/Rdata/ASTRO_data") 
if platform.system() == "Windows":
    BASEDIR = Path("R:\\ASTRO_data")  

PROJECDIR = BASEDIR / "A3_CCD_obs_raw"

PROJECDIRs = [ 
                # "STX-16803_1bin", 
                # "STX-16803_2bin",  
                # "STL-11000M_2bin", 
                # "STF-8300M_2bin",  
                # "QSI683ws_2bin", 
                # "STL-11000M_1bin",
                "STF-8300M_1bin",
                # "QSI683ws_1bin",
                # "ASI2600MC_1bin",
                "ASI6200MMPro_3bin",
                ]
DOINGDIRs = []
for DOINGDIR in PROJECDIRs:
    TODODIR = PROJECDIR / DOINGDIR              
    DOINGDIRs.extend(sorted(_Python_utilities.getFullnameListOfallsubDirs(str(TODODIR))))
if verbose == True :
    print ("DOINGDIRs: ", format(DOINGDIRs))
    print ("len(DOINGDIRs): ", format(len(DOINGDIRs)))

filter_strs = [
                '2025-0',
                # '2025-02',
                # '2025-03',
                # 'GPX-1b',
                # 'HAT',
                # 'WASP',
                ]  # Example list of filter strings
DOINGDIRs = [x for x in DOINGDIRs if any(filter_str in str(x) for filter_str in filter_strs)]

rm_filter_strs = [
                # 'GPX-1b',
                # 'HAT',
                # 'WASP',
                'DARK',
                'FLAT',
                'BIAS',
                'Bad_fits', 
                # 'Another_bad_string',
                  ]  # Example list of filter strings to remove
DOINGDIRs = [x for x in DOINGDIRs if not any(rm_filter_str in str(x) for rm_filter_str in rm_filter_strs)]

if verbose == True :
    print ("DOINGDIRs: ", DOINGDIRs)
    print ("len(DOINGDIRs): ", len(DOINGDIRs))
#######################################################
# Out:
# DOINGDIRs:  ['/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2018-12-15_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2019-03-23_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2019-03-25_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2019-04-17_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2019-05-24_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2020-03-09_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2020-03-25_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2020-03-26_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2021-12-25_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2022-01-22_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2022-04-13_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2022-08-17_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2022-09-18_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2022-10-09_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2022-10-26_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2022-11-07_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2022-11-15_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2022-11-19_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2023-06-07_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2023-06-12_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2023-09-02_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2023-09-12_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2023-10-02_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2023-10-04_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2023-10-18_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2023-11-14_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2023-11-26_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2024-05-31_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2024-06-25_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2024-11-25_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_BIAS_-_2024-12-19_-_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_DARK_-_2018-12-15_120sec_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_DARK_-_2018-12-15_30sec_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_DARK_-_2018-12-15_60sec_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_DARK_-_2018-12-15_90sec_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_DARK_-_2019-03-23_150sec_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_DARK_-_2019-03-23_200sec_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/Cal/-_DARK_-_2019-03-23_300sec_-_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_d ...
# len(DOINGDIRs):  262
# BDFDIR:  []
# DOINGDIRs:  ['/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_FSQ106ED-x73/NGC7635_LIGHT_-_2017-09-23_-_FSQ106ED-x73_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_GSON300/120LACHESIS_LIGHT_-_2023-10-09_-_GSON300_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_GSON300/1993OB2_LIGHT_-_2023-11-21_-_GSON300_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_GSON300/216KLEOPATRA_LIGHT_-_2022-10-23_-_GSON300_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_GSON300/216KLEOPATRA_LIGHT_-_2022-10-24_-_GSON300_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_GSON300/317ROXANE_LIGHT_-_2023-11-21_-_GSON300_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_GSON300/37FIDES_LIGHT_-_2023-11-21_-_GSON300_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_GSON300/48DORIS_LIGHT_-_2023-11-21_-_GSON300_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_GSON300/92UNDINA_LIGHT_-_2023-11-21_-_GSON300_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_GSON300/9628SENDAOPTSUMA_LIGHT_-_2023-11-21_-_GSON300_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_GSON300/AMO_LIGHT_-_2023-09-07_-_GSON300_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_TMB130ss/46P-WIRTANEN_LIGHT_-_2018-12-14_-_TMB130ss_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_TMB130ss/46P-WIRTANEN_LIGHT_-_2018-12-17_-_TMB130ss_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_TMB130ss/46P-WIRTANEN_LIGHT_-_2018-12-23_-_TMB130ss_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_TMB130ss/M36_LIGHT_-_2019-02-09_-_TMB130ss_STF-8300M_-_2bin//', '/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_TMB130ss/M48_LIGHT_-_2019-03-01_-_TMB130ss_STF-8300M_-_2bin//']
# len(DOINGDIRs):  16

# %% [markdown]
# ## plate solving
#
# ``DOINGDIRs``에 list 형태로 들어있는 디렉토리 경로안에 모든 파일들을 ``yfu.make_summary`` 함수를 이용하여 dataframe으로 만들어 파일명 하나하나 ``platesolving``을 수행합니다.

# %%
# example
log_dir = "logs/"
log_file = f"{log_dir}01_03_solving_raw_fits_fileMP.log"
target_string = "STF-8300M_1bin"  # 찾을 문자열

# %%
for DOINGDIR in DOINGDIRs[:1] :
    DOINGDIR = Path(DOINGDIR)
    if verbose == True :
        print("DOINGDIR", DOINGDIR)

    if _Python_utilities.check_string_in_file(log_file, DOINGDIR.name):
        print(f"'{DOINGDIR.name}' found in '{log_file}'")
        pass
    else:
        print(f"'{target_string}' not found in '{log_file}' or file does not exist.")

    SOLVINGDIR = DOINGDIR
# Out:
# DOINGDIR /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/STF-8300M_2bin/LIGHT_FSQ106ED-x73/NGC7635_LIGHT_-_2017-09-23_-_FSQ106ED-x73_STF-8300M_-_2bin
# 'NGC7635_LIGHT_-_2017-09-23_-_FSQ106ED-x73_STF-8300M_-_2bin' found in 'logs/01_03_solving_raw_fits_fileMP.log'

# %%
for DOINGDIR in DOINGDIRs[:1] :
    DOINGDIR = Path(DOINGDIR)
    if verbose == True :
        print("DOINGDIR", DOINGDIR)

    SOLVINGDIR = DOINGDIR

    summary = yfu.make_summary(SOLVINGDIR/"*.fit*")
    if summary is not None :
        if verbose == True :
            print("len(summary):", len(summary))
            print("summary:", summary)
            #print(summary["file"][0])  
        df_light = summary.loc[summary["IMAGETYP"] == "LIGHT"].copy()
        df_light = df_light.reset_index(drop=True)
        if verbose == True :
            print("df_light:\n{}".format(df_light))
    df_light

    for _, row  in df_light.iterrows():

        fpath = Path(row["file"])
        if verbose == True :
            print("fpath :" ,fpath)
        
        solved = _astro_utilities.KevinSolver(fpath, 
                                                #str(SOLVEDDIR), 
                                                # downsample = 2,
                                                # pixscale = PIXc,
                                                tryASTAP = True,  
                                                tryLOCAL = True,
                                                # makeLOCALsh = True,
                                                # tryASTROMETRYNET = False, 
                                                verbose = verbose,
                                                )
# Out:
# DOINGDIR /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin
# All 59 keywords (guessed from /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin/IC443Panel2_LIGHT_-_2024-12-31-15-25-44_600sec_OON300_ASI2600MC_-26c_1bin.fit) will be loaded.
# len(summary): 6
# summary:                                                 file  filesize  SIMPLE  \
# 0  /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC...  52191360    True
# 1  /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC...  52191360    True
# 2  /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC...  52191360    True
# 3  /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC...  52191360    True
# 4  /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC...  52191360    True
# 5  /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC...  52191360    True
#
#    BITPIX  NAXIS  NAXIS1  NAXIS2  EXTEND  BZERO IMAGETYP  ...  FOCUSTEM  \
# 0      16      2    6248    4176    True  32768    LIGHT  ...      -1.5
# 1      16      2    6248    4176    True  32768    LIGHT  ...      -1.2
# 2      16      2    6248    4176    True  32768    LIGHT  ...      -1.8
# 3      16      2    6248    4176    True  32768    LIGHT  ...      -1.5
# 4      16      2    6248    4176    True  32768    LIGHT  ...      -1.8
# 5      16      2    6248    4176    True  32768    LIGHT  ...      -2.0
#
#    ROWORDER EQUINOX                   SWCREATE FILTER    CCDNAME   OPTIC  \
# 0  TOP-DOWN  2000.0  N.I.N.A. 3.1.2.9001 (x64)      -  ASI2600MC  OON300
# 1  TOP-DOWN  2000.0  N.I.N.A. 3.1.2.9001 (x64)      -  ASI2600MC  OON300
# 2  TOP-DOWN  2000.0  N.I.N.A. 3.1.2.9001 (x64)      -  ASI2600MC  OON300
# 3  TOP-DOWN  2000.0  N.I.N.A. 3.1.2.9001 (x64)      -  ASI2600MC  OON300
# 4  TOP-DOWN  2000.0  N.I.N.A. 3.1.2.9001 (x64)      -  ASI2600MC  OON300
# 5  TOP-DOWN  2000.0  N.I.N.A. 3.1.2.9001 (x64)      -  ASI2600MC  OON300
#
#    APATURE  PIXSCALE  FLIPSTAT
# 0      300  0.646297
# 1      300  0.646297
# 2      300  0.646297
# 3      300  0.646297
# 4      300  0.646297
# 5      300  0.646297
#
# [6 rows x 61 columns]
# df_light:
#                                                 file  filesize  SIMPLE  \
# 0  /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC...  52191360    True
# 1  /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC...  52191360    True
# 2  /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC...  52191360    True
# 3  /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC...  52191360    True
# 4  /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC...  52191360    True
# 5  /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC...  52191360    True
#
#    BITPIX  NAXIS  NAXIS1  NAXIS2  EXTEND  BZERO IMAGETYP  ...  FOCUSTEM  \
# 0      16      2    6248    4176    True  32768    LIGHT  ...      -1.5
# 1      16      2    6248    4176    True  32768    LIGHT  ...      -1.2
# 2      16      2    6248    4176    True  32768    LIGHT  ...      -1.8
# 3      16      2    6248    4176    True  32768    LIGHT  ...      -1.5
# 4      16      2    6248    4176    True  32768    LIGHT  ...      -1.8
# 5      16      2    6248    4176    True  32768    LIGHT  ...      -2.0
#
#    ROWORDER EQUINOX                   SWCREATE FILTER    CCDNAME   OPTIC  \
# 0  TOP-DOWN  2000.0  N.I.N.A. 3.1.2.9001 (x64)      -  ASI2600MC  OON300
# 1  TOP-DOWN  2000.0  N.I.N.A. 3.1.2.9001 (x64)      -  ASI2600MC  OON300
# 2  TOP-DOWN  2000.0  N.I.N.A. 3.1.2.9001 (x64)      -  ASI2600MC  OON300
# 3  TOP-DOWN  2000.0  N.I.N.A. 3.1.2.9001 (x64)      -  ASI2600MC  OON300
# 4  TOP-DOWN  2000.0  N.I.N.A. 3.1.2.9001 (x64)      -  ASI2600MC  OON300
# 5  TOP-DOWN  2000.0  N.I.N.A. 3.1.2.9001 (x64)      -  ASI2600MC  OON300
#
#    APATURE  PIXSCALE  FLIPSTAT
# 0      300  0.646297
# 1      300  0.646297
# 2      300  0.646297
# 3      300  0.646297
# 4      300  0.646297
# 5      300  0.646297
#
# [6 rows x 61 columns]
# fpath : /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin/IC443Panel2_LIGHT_-_2024-12-31-15-25-44_600sec_OON300_ASI2600MC_-26c_1bin.fit
# PIXc :  0.6462969999999999
# SOLVE: False ASTAP: False LOCAL: False
# pixscale: 0.646, L: 0.627, U: 0.666
# vfov , hfov  : 1.1216843488888888 0.7497045199999999
# Trying to solve using ASTAP:
#    /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin/IC443Panel2_LIGHT_-_2024-12-31-15-25-44_600sec_OON300_ASI2600MC_-26c_1bin.fit
# --wcs -analyse2 -update
# SOLVE: False ASTAP: False LOCAL: False
# ASTAP : trying again downsample X 2 :
#    /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin/IC443Panel2_LIGHT_-_2024-12-31-15-25-44_600sec_OON300_ASI2600MC_-26c_1bin.fit
# --wcs -analyse2 -update
# SOLVE: False ASTAP: False LOCAL: False
# Trying to solve using LOCAL:
#    /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin/IC443Panel2_LIGHT_-_2024-12-31-15-25-44_600sec_OON300_ASI2600MC_-26c_1bin.fit
# solve-field -O --cpulimit 30 -g --nsigma 15 --downsample 4 --no-plots /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin/IC443Panel2_LIGHT_-_2024-12-31-15-25-44_600sec_OON300_ASI2600MC_-26c_1bin.fit
# Reading input file 1 of 1: "/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin/IC443Panel2_LIGHT_-_2024-12-31-15-25-44_600sec_OON300_ASI2600MC_-26c_1bin.fit"...
# sh: 1: --wcs: not found
# sh: 1: --wcs: not found
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1272 sources.
# Solving...
# Reading file "/mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin/IC443Panel2_LIGHT_-_2024-12-31-15-25-44_600sec_OON300_ASI2600MC_-26c_1bin.axy"...
# Field 1 did not solve (index index-4210.fits, field objects 1-10).
# Field 1 did not solve (index index-4209.fits, field objects 1-10).
# Field 1 did not solve (index index-4208.fits, field objects 1-10).
# Field 1 did not solve (index index-4207-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4207-10.fits, field objects 1-10).
# Field 1 did not solve (index index-4207-09.fits, field objects 1-10).
# Field 1 did not solve (index index-4207-08.fits, field objects 1-10).
# Field 1 did not solve (index index-4207-07.fits, field objects 1-10).
# Field 1 did not solve (index index-4207-06.fits, field objects 1-10).
# Field 1 did not solve (index index-4207-05.fits, field objects 1-10).
# Field 1 did not solve (index index-4207-04.fits, field objects 1-10).
# Field 1 did not solve (index index-4207-03.fits, field objects 1-10).
# Field 1 did not solve (index index-4207-02.fits, field objects 1-10).
# Field 1 did not solve (index index-4207-01.fits, field objects 1-10).
# Field 1 did not solve (index index-4207-00.fits, field objects 1-10).
# Field 1 did not solve (index index-4206-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4206-10.fits, field objects 1-10).
# Field 1 did not solve (index index-4206-09.fits, field objects 1-10).
# Field 1 did not solve (index index-4206-08.fits, field objects 1-10).
# Field 1 did not solve (index index-4206-07.fits, field objects 1-10).
# Field 1 did not solve (index index-4206-06.fits, field objects 1-10).
# Field 1 did not solve (index index-4206-05.fits, field objects 1-10).
# Field 1 did not solve (index index-4206-04.fits, field objects 1-10).
# Field 1 did not solve (index index-4206-03.fits, field objects 1-10).
# Field 1 did not solve (index index-4206-02.fits, field objects 1-10).
# Field 1 did not solve (index index-4206-01.fits, field objects 1-10).
# Field 1 did not solve (index index-4206-00.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-10.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-09.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-08.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-07.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-06.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-05.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-04.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-03.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-02.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-01.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-00.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-46.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-45.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-44.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-43.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-42.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-41.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-40.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-39.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-38.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-37.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-36.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-35.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-34.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-33.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-32.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-31.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-30.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-29.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-28.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-27.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-26.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-25.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-24.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-23.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-22.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-21.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-20.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-19.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-18.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-17.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-16.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-15.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-14.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-13.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-12.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-10.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-09.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-08.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-07.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-06.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-05.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-04.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-03.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-02.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-01.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-00.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-46.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-45.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-44.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-43.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-42.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-41.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-40.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-39.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-38.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-37.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-36.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-35.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-34.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-33.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-32.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-31.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-30.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-29.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-28.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-27.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-26.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-25.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-24.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-23.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-22.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-21.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-20.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-19.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-18.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-17.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-16.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-15.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-14.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-13.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-12.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-10.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-09.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-08.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-07.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-06.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-05.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-04.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-03.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-02.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-01.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-00.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-46.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-45.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-44.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-43.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-42.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-41.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-40.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-39.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-38.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-37.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-36.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-35.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-34.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-33.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-32.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-31.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-30.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-29.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-28.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-27.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-26.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-25.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-24.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-23.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-22.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-21.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-20.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-19.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-18.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-17.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-16.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-15.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-14.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-13.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-12.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-10.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-09.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-08.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-07.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-06.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-05.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-04.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-03.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-02.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-01.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-00.fits, field objects 1-10).
# Field 1 did not solve (index index-4210.fits, field objects 11-20).
# Field 1 did not solve (index index-4209.fits, field objects 11-20).
# Field 1 did not solve (index index-4208.fits, field objects 11-20).
# Field 1 did not solve (index index-4207-11.fits, field objects 11-20).
# Field 1 did not solve (index index-4207-10.fits, field objects 11-20).
# Field 1 did not solve (index index-4207-09.fits, field objects 11-20).
# Field 1 did not solve (index index-4207-08.fits, field objects 11-20).
# Field 1 did not solve (index index-4207-07.fits, field objects 11-20).
# Field 1 did not solve (index index-4207-06.fits, field objects 11-20).
# Field 1 did not solve (index index-4207-05.fits, field objects 11-20).
# Field 1 did not solve (index index-4207-04.fits, field objects 11-20).
# Field 1 did not solve (index index-4207-03.fits, field objects 11-20).
# Field 1 did not solve (index index-4207-02.fits, field objects 11-20).
# Field 1 did not solve (index index-4207-01.fits, field objects 11-20).
# Field 1 did not solve (index index-4207-00.fits, field objects 11-20).
# Field 1 did not solve (index index-4206-11.fits, field objects 11-20).
# Field 1 did not solve (index index-4206-10.fits, field objects 11-20).
# Field 1 did not solve (index index-4206-09.fits, field objects 11-20).
# Field 1 did not solve (index index-4206-08.fits, field objects 11-20).
# Field 1 did not solve (index index-4206-07.fits, field objects 11-20).
# Field 1 did not solve (index index-4206-06.fits, field objects 11-20).
# Field 1 did not solve (index index-4206-05.fits, field objects 11-20).
# Field 1 did not solve (index index-4206-04.fits, field objects 11-20).
# Field 1 did not solve (index index-4206-03.fits, field objects 11-20).
# Field 1 did not solve (index index-4206-02.fits, field objects 11-20).
# Field 1 did not solve (index index-4206-01.fits, field objects 11-20).
# Field 1 did not solve (index index-4206-00.fits, field objects 11-20).
# Field 1 did not solve (index index-4205-11.fits, field objects 11-20).
# Field 1 did not solve (index index-4205-10.fits, field objects 11-20).
# Field 1 did not solve (index index-4205-09.fits, field objects 11-20).
# Field 1 did not solve (index index-4205-08.fits, field objects 11-20).
# Field 1 did not solve (index index-4205-07.fits, field objects 11-20).
# Field 1 did not solve (index index-4205-06.fits, field objects 11-20).
# Field 1 did not solve (index index-4205-05.fits, field objects 11-20).
# Field 1 did not solve (index index-4205-04.fits, field objects 11-20).
# Field 1 did not solve (index index-4205-03.fits, field objects 11-20).
# Field 1 did not solve (index index-4205-02.fits, field objects 11-20).
# Field 1 did not solve (index index-4205-01.fits, field objects 11-20).
# Field 1 did not solve (index index-4205-00.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-47.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-46.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-45.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-44.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-43.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-42.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-41.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-40.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-39.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-38.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-37.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-36.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-35.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-34.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-33.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-32.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-31.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-30.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-29.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-28.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-27.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-26.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-25.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-24.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-23.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-22.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-21.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-20.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-19.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-18.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-17.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-16.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-15.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-14.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-13.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-12.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-11.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-10.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-09.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-08.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-07.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-06.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-05.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-04.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-03.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-02.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-01.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-00.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-47.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-46.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-45.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-44.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-43.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-42.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-41.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-40.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-39.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-38.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-37.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-36.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-35.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-34.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-33.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-32.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-31.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-30.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-29.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-28.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-27.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-26.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-25.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-24.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-23.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-22.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-21.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-20.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-19.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-18.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-17.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-16.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-15.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-14.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-13.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-12.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-11.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-10.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-09.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-08.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-07.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-06.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-05.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-04.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-03.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-02.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-01.fits, field objects 11-20).
# Field 1 did not solve (index index-4203-00.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-47.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-46.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-45.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-44.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-43.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-42.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-41.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-40.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-39.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-38.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-37.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-36.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-35.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-34.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-33.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-32.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-31.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-30.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-29.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-28.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-27.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-26.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-25.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-24.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-23.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-22.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-21.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-20.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-19.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-18.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-17.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-16.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-15.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-14.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-13.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-12.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-11.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-10.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-09.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-08.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-07.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-06.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-05.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-04.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-03.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-02.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-01.fits, field objects 11-20).
# Field 1 did not solve (index index-4202-00.fits, field objects 11-20).
# Field 1 did not solve (index index-4210.fits, field objects 21-30).
# Field 1 did not solve (index index-4209.fits, field objects 21-30).
# Field 1 did not solve (index index-4208.fits, field objects 21-30).
# Field 1 did not solve (index index-4207-11.fits, field objects 21-30).
# Field 1 did not solve (index index-4207-10.fits, field objects 21-30).
# Field 1 did not solve (index index-4207-09.fits, field objects 21-30).
# Field 1 did not solve (index index-4207-08.fits, field objects 21-30).
# Field 1 did not solve (index index-4207-07.fits, field objects 21-30).
# Field 1 did not solve (index index-4207-06.fits, field objects 21-30).
# Field 1 did not solve (index index-4207-05.fits, field objects 21-30).
# Field 1 did not solve (index index-4207-04.fits, field objects 21-30).
# Field 1 did not solve (index index-4207-03.fits, field objects 21-30).
# Field 1 did not solve (index index-4207-02.fits, field objects 21-30).
# Field 1 did not solve (index index-4207-01.fits, field objects 21-30).
# Field 1 did not solve (index index-4207-00.fits, field objects 21-30).
# Field 1 did not solve (index index-4206-11.fits, field objects 21-30).
# Field 1 did not solve (index index-4206-10.fits, field objects 21-30).
# Field 1 did not solve (index index-4206-09.fits, field objects 21-30).
# Field 1 did not solve (index index-4206-08.fits, field objects 21-30).
# Field 1 did not solve (index index-4206-07.fits, field objects 21-30).
# Field 1 did not solve (index index-4206-06.fits, field objects 21-30).
# Field 1 did not solve (index index-4206-05.fits, field objects 21-30).
# Field 1 did not solve (index index-4206-04.fits, field objects 21-30).
# Field 1 did not solve (index index-4206-03.fits, field objects 21-30).
# Field 1 did not solve (index index-4206-02.fits, field objects 21-30).
# Field 1 did not solve (index index-4206-01.fits, field objects 21-30).
# Field 1 did not solve (index index-4206-00.fits, field objects 21-30).
# Field 1 did not solve (index index-4205-11.fits, field objects 21-30).
# Field 1 did not solve (index index-4205-10.fits, field objects 21-30).
# Field 1 did not solve (index index-4205-09.fits, field objects 21-30).
# Field 1 did not solve (index index-4205-08.fits, field objects 21-30).
# Field 1 did not solve (index index-4205-07.fits, field objects 21-30).
# Field 1 did not solve (index index-4205-06.fits, field objects 21-30).
# Field 1 did not solve (index index-4205-05.fits, field objects 21-30).
# Field 1 did not solve (index index-4205-04.fits, field objects 21-30).
# Field 1 did not solve (index index-4205-03.fits, field objects 21-30).
# Field 1 did not solve (index index-4205-02.fits, field objects 21-30).
# Field 1 did not solve (index index-4205-01.fits, field objects 21-30).
# Field 1 did not solve (index index-4205-00.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-47.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-46.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-45.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-44.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-43.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-42.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-41.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-40.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-39.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-38.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-37.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-36.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-35.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-34.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-33.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-32.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-31.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-30.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-29.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-28.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-27.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-26.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-25.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-24.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-23.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-22.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-21.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-20.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-19.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-18.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-17.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-16.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-15.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-14.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-13.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-12.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-11.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-10.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-09.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-08.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-07.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-06.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-05.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-04.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-03.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-02.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-01.fits, field objects 21-30).
# Field 1 did not solve (index index-4204-00.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-47.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-46.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-45.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-44.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-43.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-42.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-41.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-40.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-39.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-38.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-37.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-36.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-35.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-34.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-33.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-32.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-31.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-30.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-29.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-28.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-27.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-26.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-25.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-24.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-23.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-22.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-21.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-20.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-19.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-18.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-17.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-16.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-15.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-14.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-13.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-12.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-11.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-10.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-09.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-08.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-07.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-06.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-05.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-04.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-03.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-02.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-01.fits, field objects 21-30).
# Field 1 did not solve (index index-4203-00.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-47.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-46.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-45.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-44.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-43.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-42.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-41.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-40.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-39.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-38.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-37.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-36.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-35.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-34.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-33.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-32.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-31.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-30.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-29.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-28.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-27.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-26.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-25.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-24.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-23.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-22.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-21.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-20.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-19.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-18.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-17.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-16.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-15.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-14.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-13.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-12.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-11.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-10.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-09.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-08.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-07.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-06.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-05.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-04.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-03.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-02.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-01.fits, field objects 21-30).
# Field 1 did not solve (index index-4202-00.fits, field objects 21-30).
# Field 1 did not solve (index index-4210.fits, field objects 31-40).
# Field 1 did not solve (index index-4209.fits, field objects 31-40).
# Field 1 did not solve (index index-4208.fits, field objects 31-40).
# Field 1 did not solve (index index-4207-11.fits, field objects 31-40).
# Field 1 did not solve (index index-4207-10.fits, field objects 31-40).
# Field 1 did not solve (index index-4207-09.fits, field objects 31-40).
# Field 1 did not solve (index index-4207-08.fits, field objects 31-40).
# Field 1 did not solve (index index-4207-07.fits, field objects 31-40).
# Field 1 did not solve (index index-4207-06.fits, field objects 31-40).
# Field 1 did not solve (index index-4207-05.fits, field objects 31-40).
# Field 1 did not solve (index index-4207-04.fits, field objects 31-40).
# Field 1 did not solve (index index-4207-03.fits, field objects 31-40).
# Field 1 did not solve (index index-4207-02.fits, field objects 31-40).
# Field 1 did not solve (index index-4207-01.fits, field objects 31-40).
# Field 1 did not solve (index index-4207-00.fits, field objects 31-40).
# Field 1 did not solve (index index-4206-11.fits, field objects 31-40).
# Field 1 did not solve (index index-4206-10.fits, field objects 31-40).
# Field 1 did not solve (index index-4206-09.fits, field objects 31-40).
# Field 1 did not solve (index index-4206-08.fits, field objects 31-40).
# Field 1 did not solve (index index-4206-07.fits, field objects 31-40).
# Field 1 did not solve (index index-4206-06.fits, field objects 31-40).
# Field 1 did not solve (index index-4206-05.fits, field objects 31-40).
# Field 1 did not solve (index index-4206-04.fits, field objects 31-40).
# Field 1 did not solve (index index-4206-03.fits, field objects 31-40).
# Field 1 did not solve (index index-4206-02.fits, field objects 31-40).
# Field 1 did not solve (index index-4206-01.fits, field objects 31-40).
# Field 1 did not solve (index index-4206-00.fits, field objects 31-40).
# Field 1 did not solve (index index-4205-11.fits, field objects 31-40).
# Field 1 did not solve (index index-4205-10.fits, field objects 31-40).
# Field 1 did not solve (index index-4205-09.fits, field objects 31-40).
# Field 1 did not solve (index index-4205-08.fits, field objects 31-40).
# Field 1 did not solve (index index-4205-07.fits, field objects 31-40).
# Field 1 did not solve (index index-4205-06.fits, field objects 31-40).
# Field 1 did not solve (index index-4205-05.fits, field objects 31-40).
# Field 1 did not solve (index index-4205-04.fits, field objects 31-40).
# Field 1 did not solve (index index-4205-03.fits, field objects 31-40).
# Field 1 did not solve (index index-4205-02.fits, field objects 31-40).
# Field 1 did not solve (index index-4205-01.fits, field objects 31-40).
# Field 1 did not solve (index index-4205-00.fits, field objects 31-40).
# Field 1 did not solve (index index-4204-47.fits, field objects 31-40).
# Field 1 did not solve (index index-4204-46.fits, field objects 31-40).
# Field 1 did not solve (index index-4204-45.fits, field objects 31-40).
# Field 1 did not solve (index index-4204-44.fits, field objects 31-40).
# ...
# Field 1 did not solve (index index-4205-00.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-47.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-46.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-45.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-44.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-43.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-42.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-41.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-40.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-39.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-38.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-37.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-36.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-35.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-34.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-33.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-32.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-31.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-30.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-29.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-28.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-27.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-26.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-25.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-24.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-23.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-22.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-21.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-20.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-19.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-18.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-17.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-16.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-15.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-14.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-13.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-12.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-11.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-10.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-09.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-08.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-07.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-06.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-05.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-04.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-03.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-02.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-01.fits, field objects 161-170).
# Field 1 did not solve (index index-4204-00.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-47.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-46.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-45.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-44.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-43.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-42.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-41.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-40.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-39.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-38.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-37.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-36.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-35.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-34.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-33.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-32.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-31.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-30.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-29.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-28.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-27.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-26.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-25.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-24.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-23.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-22.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-21.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-20.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-19.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-18.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-17.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-16.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-15.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-14.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-13.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-12.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-11.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-10.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-09.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-08.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-07.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-06.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-05.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-04.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-03.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-02.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-01.fits, field objects 161-170).
# Field 1 did not solve (index index-4203-00.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-47.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-46.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-45.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-44.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-43.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-42.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-41.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-40.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-39.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-38.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-37.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-36.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-35.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-34.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-33.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-32.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-31.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-30.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-29.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-28.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-27.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-26.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-25.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-24.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-23.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-22.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-21.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-20.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-19.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-18.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-17.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-16.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-15.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-14.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-13.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-12.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-11.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-10.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-09.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-08.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-07.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-06.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-05.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-04.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-03.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-02.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-01.fits, field objects 161-170).
# Field 1 did not solve (index index-4202-00.fits, field objects 161-170).
# Field 1 did not solve (index index-4210.fits, field objects 171-180).
# Field 1 did not solve (index index-4209.fits, field objects 171-180).
# Field 1 did not solve (index index-4208.fits, field objects 171-180).
# Field 1 did not solve (index index-4207-11.fits, field objects 171-180).
# Field 1 did not solve (index index-4207-10.fits, field objects 171-180).
# Field 1 did not solve (index index-4207-09.fits, field objects 171-180).
# Field 1 did not solve (index index-4207-08.fits, field objects 171-180).
# Field 1 did not solve (index index-4207-07.fits, field objects 171-180).
# Total CPU time limit reached!
# Field 1 did not solve (index index-4207-06.fits, field objects 171-180).
# Field: /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin/IC443Panel2_LIGHT_-_2024-12-31-15-25-44_600sec_OON300_ASI2600MC_-26c_1bin.fit
# Did not solve (or no WCS file was written).
#
# SOLVE: False ASTAP: False LOCAL: False
# LOCAL : traagain downsample X 2:
#    /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin/IC443Panel2_LIGHT_-_2024-12-31-15-25-44_600sec_OON300_ASI2600MC_-26c_1bin.fit
# solve-field -O --cpulimit 30 -g --nsigma 15 --downsample 8 --scale-units app app -L 0.614 -H 0.679 --no-plots /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin/IC443Panel2_LIGHT_-_2024-12-31-15-25-44_600sec_OON300_ASI2600MC_-26c_1bin.fit
# Reading input file 1 of 2: "app"...
# SOLVE: False ASTAP: False LOCAL: False
# Trying to solve using astrometry:
#   /mnt/Rdata/ASTRO_data/A3_CCD_obs_raw/ASI2600MC_1bin/LIGHT_OON300/IC443Panel2_LIGHT_-_2024-12-31_-_OON300_ASI2600MC_-_1bin/IC443Panel2_LIGHT_-_2024-12-31-15-25-44_600sec_OON300_ASI2600MC_-26c_1bin.fit
# ERROR: Image type not recognized: Unknown image type "["cannot open `app' (No such file or directory)"]"
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/astrometry/util/image2pnm.py", line 298, in main
#     convert_image(options.infile, options.outfile,
#   File "/usr/lib/python3/dist-packages/astrometry/util/image2pnm.py", line 242, in convert_image
#     raise RuntimeError(errstr)
# RuntimeError: Image type not recognized: Unknown image type "["cannot open `app' (No such file or directory)"]"
# augment-xylist.c:591:backtick Failed to run command: /usr/bin/python3 -m astrometry.util.image2pnm --infile app --uncompressed-outfile /tmp/tmp.uncompressed.AQg24t --outfile /tmp/tmp.ppm.cyTDzw --ppm --mydir /usr/bin/solve-field
#  ioutils.c:568:run_command_get_outputs Command failed: return value 255
# Solving.....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 39
#      36     print("PIXc : ", PIXc)
#      37 hdul.close()
# ---> 39 solved = _astro_utilities.KevinSolver(fpath,
#      40                                         #str(SOLVEDDIR),
#      41                                         # downsample = 2,
#      42                                         # pixscale = PIXc,
#      43                                         tryASTAP = True,
#      44                                         tryLOCAL = True,
#      45                                         # makeLOCALsh = True,
#      46                                         # tryASTROMETRYNET = False,
#      47                                         verbose = verbose,
#      48                                         )
#
# File ~/Desktop/KBox/Github/astro_Python/_astro_utilities.py:999, in KevinSolver(fpath, solved_dir, downsample, pixscale, cpulimit, SOLVE, nsigma, tryASTAP, tryLOCAL, tryASTROMETRYNET, makeLOCALsh, verbose, **kwargs)
#     997 try:
#     998     if not submission_id:
# --> 999         wcs_header = ast.solve_from_image(str(fpath),
#    1000                             force_image_upload=True,
#    1001                             solve_timeout = solve_timeout,
#    1002                             submission_id=submission_id)
#    1003     else:
#    1004         wcs_header = ast.monitor_submission(submission_id,
#    1005                                             solve_timeout = solve_timeout)
#
# File ~/anaconda3/envs/astro_Python_env/lib/python3.10/site-packages/astroquery/astrometry_net/core.py:460, in AstrometryNetClass.solve_from_image(self, image_file_path, force_image_upload, ra_key, dec_key, ra_dec_units, fwhm, detect_threshold, solve_timeout, verbose, return_submission_id, **settings)
#     458 response_d = response.json()
#     459 submission_id = response_d['subid']
# --> 460 return self.monitor_submission(submission_id,
#     461                                solve_timeout=solve_timeout,
#     462                                verbose=verbose,
#     463                                return_submission_id=return_submission_id)
#
# File ~/anaconda3/envs/astro_Python_env/lib/python3.10/site-packages/astroquery/astrometry_net/core.py:246, in AstrometryNetClass.monitor_submission(self, submission_id, solve_timeout, verbose, return_submission_id)
#     244 status = ''
#     245 while not has_completed:
# --> 246     time.sleep(1)
#     247     sub_stat_url = url_helpers.join(self.API_URL, 'submissions', str(submission_id))
#     248     sub_stat = self._request('GET', sub_stat_url, cache=False)
#
# KeyboardInterrupt:
